# %%
import os
import numpy as np
import pandas as pd

# Paths
input_dir = "data"
output_dir = "increase_data/sitting"

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Load existing data files
existing_files = [f"data_sitting_{i}.csv" for i in range(1, 6)]
existing_data = [pd.read_csv(os.path.join(input_dir, file), header=None).values for file in existing_files]

# Function to interpolate between two datasets
def interpolate_data(data1, data2, alpha=0.5):
    """Interpolates two time-series data maintaining row-to-row relationships."""
    return alpha * data1 + (1 - alpha) * data2

# Function to ensure exactly 100 rows
def ensure_100_rows(data):
    """Trims or up-samples data to ensure exactly 100 rows."""
    num_rows = data.shape[0]

    if num_rows > 100:
        return data[:100]  # Trim excess rows
    elif num_rows < 100:
        extra_rows = 100 - num_rows
        interp_rows = np.linspace(0, num_rows - 1, extra_rows, dtype=int)
        extra_data = data[interp_rows]
        return np.vstack([data, extra_data])
    return data  # Already 100 rows

# Generate 100 new files
for i in range(1, 101):
    # Select two random datasets for interpolation
    idx1, idx2 = np.random.choice(len(existing_data), 2, replace=False)
    data1, data2 = existing_data[idx1], existing_data[idx2]

    # Random interpolation factor
    alpha = np.random.uniform(0.3, 0.7)  # To introduce more variation

    # Interpolate and ensure shape
    new_data = interpolate_data(data1, data2, alpha)
    new_data = ensure_100_rows(new_data)  # Ensure 100 rows

    # Save the new data
    output_file = os.path.join(output_dir, f"data_sitting_{i}.csv")
    pd.DataFrame(new_data).to_csv(output_file, header=False, index=False)

    print(f"Generated: {output_file} (Shape: {new_data.shape})")

print("Data augmentation complete. 100 files created!")
# Out:
# Generated: increase_data/sitting\data_sitting_1.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_2.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_3.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_4.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_5.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_6.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_7.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_8.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_9.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_10.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_11.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_12.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_13.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_14.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_15.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_16.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_17.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_18.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_19.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_20.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_21.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_22.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_23.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_24.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_25.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_26.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_27.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_28.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_29.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_30.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_31.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_32.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_33.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_34.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_35.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_36.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_37.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_38.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_39.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_40.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_41.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_42.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_43.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_44.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_45.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_46.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_47.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_48.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_49.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_50.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_51.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_52.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_53.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_54.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_55.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_56.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_57.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_58.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_59.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_60.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_61.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_62.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_63.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_64.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_65.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_66.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_67.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_68.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_69.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_70.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_71.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_72.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_73.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_74.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_75.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_76.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_77.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_78.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_79.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_80.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_81.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_82.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_83.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_84.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_85.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_86.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_87.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_88.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_89.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_90.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_91.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_92.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_93.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_94.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_95.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_96.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_97.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_98.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_99.csv (Shape: (100, 132))
# Generated: increase_data/sitting\data_sitting_100.csv (Shape: (100, 132))
# Data augmentation complete. 100 files created!

# %%
import os
import numpy as np
import pandas as pd

# Paths
input_dir = "data"
output_dir = "increase_data/standing"

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Load existing data files
existing_files = [f"data_standing_{i}.csv" for i in range(1, 18)]
existing_data = [pd.read_csv(os.path.join(input_dir, file), header=None).values for file in existing_files]

# Function to interpolate between two datasets
def interpolate_data(data1, data2, alpha=0.5):
    """Interpolates two time-series data maintaining row-to-row relationships."""
    return alpha * data1 + (1 - alpha) * data2

# Function to ensure exactly 100 rows
def ensure_100_rows(data):
    """Trims or up-samples data to ensure exactly 100 rows."""
    num_rows = data.shape[0]

    if num_rows > 100:
        return data[:100]  # Trim excess rows
    elif num_rows < 100:
        extra_rows = 100 - num_rows
        interp_rows = np.linspace(0, num_rows - 1, extra_rows, dtype=int)
        extra_data = data[interp_rows]
        return np.vstack([data, extra_data])
    return data  # Already 100 rows

# Generate 100 new files
for i in range(1, 101):
    # Select two random datasets for interpolation
    idx1, idx2 = np.random.choice(len(existing_data), 2, replace=False)
    data1, data2 = existing_data[idx1], existing_data[idx2]

    # Interpolation factor
    alpha = np.random.uniform(0.3, 0.7)  # To introduce more variation

    # Interpolate and ensure shape
    new_data = interpolate_data(data1, data2, alpha)
    new_data = ensure_100_rows(new_data)  # Ensure 100 rows

    # Save the new data
    output_file = os.path.join(output_dir, f"data_standing_{i}.csv")
    pd.DataFrame(new_data).to_csv(output_file, header=False, index=False)

    print(f"Generated: {output_file} (Shape: {new_data.shape})")

print("Data augmentation complete. 100 files created!")
# Out:
# Generated: increase_data/standing\data_standing_1.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_2.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_3.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_4.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_5.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_6.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_7.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_8.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_9.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_10.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_11.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_12.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_13.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_14.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_15.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_16.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_17.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_18.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_19.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_20.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_21.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_22.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_23.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_24.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_25.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_26.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_27.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_28.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_29.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_30.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_31.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_32.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_33.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_34.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_35.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_36.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_37.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_38.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_39.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_40.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_41.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_42.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_43.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_44.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_45.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_46.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_47.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_48.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_49.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_50.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_51.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_52.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_53.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_54.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_55.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_56.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_57.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_58.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_59.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_60.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_61.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_62.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_63.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_64.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_65.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_66.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_67.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_68.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_69.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_70.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_71.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_72.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_73.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_74.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_75.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_76.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_77.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_78.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_79.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_80.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_81.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_82.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_83.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_84.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_85.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_86.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_87.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_88.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_89.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_90.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_91.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_92.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_93.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_94.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_95.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_96.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_97.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_98.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_99.csv (Shape: (100, 132))
# Generated: increase_data/standing\data_standing_100.csv (Shape: (100, 132))
# Data augmentation complete. 100 files created!

# %%
import os
import numpy as np
import pandas as pd

# Paths
input_dir = "data"
output_dir = "increase_data/falling"  # Fixed typo: "stitting" -> "sitting"

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Load existing data files
existing_files = [f"data_falling_{i}.csv" for i in range(1, 20)]
existing_data = [pd.read_csv(os.path.join(input_dir, file), header=None).values for file in existing_files]

# Function to interpolate between two datasets
def interpolate_data(data1, data2, alpha=0.5):
    """Interpolates two time-series data maintaining row-to-row relationships."""
    return alpha * data1 + (1 - alpha) * data2

# Function to ensure 100 rows in the dataset
def ensure_100_rows(data):
    """Trims or up-samples data to ensure exactly 100 rows."""
    num_rows = data.shape[0]

    if num_rows > 100:
        return data[:100]  # Trim excess rows
    elif num_rows < 100:
        # Interpolate additional rows to reach 100
        extra_rows = 100 - num_rows
        interp_rows = np.linspace(0, num_rows - 1, extra_rows, dtype=int)
        extra_data = data[interp_rows]
        return np.vstack([data, extra_data])
    return data  # Already 100 rows

# Generate 100 new files
for i in range(1, 101):
    # Select two random datasets for interpolation
    idx1, idx2 = np.random.choice(len(existing_data), 2, replace=False)
    data1, data2 = existing_data[idx1], existing_data[idx2]

    # Interpolation factor
    alpha = np.random.uniform(0.3, 0.7)  # To introduce more variation

    # Interpolate and ensure shape
    new_data = interpolate_data(data1, data2, alpha)
    new_data = ensure_100_rows(new_data)  # Ensure 100 rows

    # Save the new data
    output_file = os.path.join(output_dir, f"data_falling_{i}.csv")
    pd.DataFrame(new_data).to_csv(output_file, header=False, index=False)

    print(f"Generated: {output_file} (Shape: {new_data.shape})")

print("Data augmentation complete. 100 files created!")
# Out:
# Generated: increase_data/falling\data_falling_1.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_2.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_3.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_4.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_5.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_6.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_7.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_8.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_9.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_10.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_11.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_12.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_13.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_14.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_15.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_16.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_17.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_18.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_19.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_20.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_21.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_22.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_23.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_24.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_25.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_26.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_27.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_28.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_29.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_30.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_31.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_32.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_33.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_34.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_35.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_36.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_37.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_38.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_39.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_40.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_41.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_42.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_43.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_44.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_45.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_46.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_47.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_48.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_49.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_50.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_51.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_52.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_53.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_54.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_55.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_56.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_57.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_58.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_59.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_60.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_61.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_62.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_63.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_64.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_65.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_66.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_67.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_68.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_69.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_70.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_71.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_72.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_73.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_74.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_75.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_76.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_77.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_78.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_79.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_80.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_81.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_82.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_83.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_84.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_85.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_86.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_87.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_88.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_89.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_90.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_91.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_92.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_93.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_94.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_95.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_96.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_97.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_98.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_99.csv (Shape: (100, 132))
# Generated: increase_data/falling\data_falling_100.csv (Shape: (100, 132))
# Data augmentation complete. 100 files created!
